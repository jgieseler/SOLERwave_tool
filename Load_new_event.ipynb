# %% [markdown]
# ## Custom File Handler
#
# In order to find a new event, the search_new_event function of the SOLERwave tool is used. It is based on sunpys fido search function.
#
# It produces a folder structure for the data at the defined "path", downloads images of the defined instrument and preprocesses these images by derotating, binning and calculating the base ratio.
#
# Currently, the following instruments are implemented:
# - SDO/AIA as 'aia'
# - STEREO/SECCHI as 'secchi'
# - GONG/H-alpha as 'gong' $^1$
# - Kanzelhoehe/H-alpha as 'ha2'
#
# For a successful search, the following arguments are required:
# - path for the data
# - start time
# - end time
# - Instrument name
# - Wavelength $^2$
#
# Notes:
# - $^1$ Technically gong is the source, not the instrument when it comes to H-alpha data. Calling "search_new_event" with 'gong' will result in a summary of which observatory was active during the time. For an actual download the function has to be called with the name of one of these observatories (see Example 2 for more information).
#
# - $^2$ For H-alpha observation the wavelength should be 6562.8 Angstrom

# %%
import astropy.units as u
from SOLERwaves_custom_file_handler import search_new_event

# %% [markdown]
# ## Example 1: SDO/AIA, 211$\AA$, 2022 March 10
#
# Example 1 is a nice wave observed on the 06.th of September 2011 and was already characterised by Dissauer et al. 2016.
#
# Note for AIA observations: to download data form the jsoc server, a jsoc_notify_mail is needed. This can be created via http://jsoc.stanford.edu/ajax/register_email.html

# %%
jsoc_notify_mail_ = 'Insert your e-mail address here'

#To shift results in a combined folder, replace '' with 'data_folder' and 
# create the folder 'data_folder' in the same folder you run this code in 
search_new_event('', '2011-09-06T22:15:50','2011-09-06T22:16:20',
                jsoc_notify_mail=jsoc_notify_mail_, Instrument_Name='aia',
                Wavelength_=211 * u.AA)
# Out:
# 15:09:40 custom_sunpy_file_handler: folder successfully created
# 2026-02-23 15:09:53 - drms - INFO: Export request pending. [id=JSOC_20260223_003206, status=2]
# 2026-02-23 15:09:53 - drms - INFO: Waiting for 0 seconds...
# 2026-02-23 15:09:57 - drms - INFO: Export request pending. [id=JSOC_20260223_003206, status=1]
# 2026-02-23 15:09:57 - drms - INFO: Waiting for 5 seconds...
# 2026-02-23 15:10:03 - drms - INFO: Export request pending. [id=JSOC_20260223_003206, status=1]
# 2026-02-23 15:10:03 - drms - INFO: Waiting for 5 seconds...
# 2026-02-23 15:10:08 - drms - INFO: Export request pending. [id=JSOC_20260223_003206, status=1]
# 2026-02-23 15:10:08 - drms - INFO: Waiting for 5 seconds...
# 2026-02-23 15:10:14 - drms - INFO: Export request pending. [id=JSOC_20260223_003206, status=1]
# 2026-02-23 15:10:14 - drms - INFO: Waiting for 5 seconds...
# 2026-02-23 15:10:20 - drms - INFO: Export request pending. [id=JSOC_20260223_003206, status=1]
# 2026-02-23 15:10:20 - drms - INFO: Waiting for 5 seconds...
# 2026-02-23 15:10:25 - drms - INFO: Export request pending. [id=JSOC_20260223_003206, status=1]
# 2026-02-23 15:10:25 - drms - INFO: Waiting for 5 seconds...
# 2026-02-23 15:10:31 - sunpy - INFO: 3 URLs found for download. Full request totaling 32MB
# INFO: 3 URLs found for download. Full request totaling 32MB [sunpy.net.jsoc.jsoc]
# Files Downloaded:   0%|          | 0/3 [00:00<?, ?file/s]
# aia.lev1_euv_12s.2011-09-06T221550Z.211.image_lev1.fits:   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# aia.lev1_euv_12s.2011-09-06T221602Z.211.image_lev1.fits:   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# aia.lev1_euv_12s.2011-09-06T221614Z.211.image_lev1.fits:   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# 2026-02-23 15:11:45 - astropy - WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU.
# 15:11:45 custom_sunpy_file_handler: binning active 2x2 pixel
# 15:11:45 custom_sunpy_file_handler: process image: 1 of 2
# WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data. [sunpy.map.mapbase]
# 2026-02-23 15:11:45 - sunpy - WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data.
# 2026-02-23 15:11:45 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# 2026-02-23 15:12:15 - astropy - WARNING: VerifyWarning: Verification reported errors:
# WARNING: VerifyWarning: HDU 0: [astropy.io.fits.verify]
# 2026-02-23 15:12:15 - astropy - WARNING: VerifyWarning: HDU 0:
# WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3). [astropy.io.fits.verify]
# 2026-02-23 15:12:15 - astropy - WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3).
# WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4). [astropy.io.fits.verify]
# 2026-02-23 15:12:15 - astropy - WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4).
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# 2026-02-23 15:12:15 - astropy - WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
# 15:12:15 custom_sunpy_file_handler: process image: 2 of 2
# WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data. [sunpy.map.mapbase]
# 2026-02-23 15:12:15 - sunpy - WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data.
# 2026-02-23 15:12:15 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# 2026-02-23 15:12:41 - astropy - WARNING: VerifyWarning: Verification reported errors:
# WARNING: VerifyWarning: HDU 0: [astropy.io.fits.verify]
# 2026-02-23 15:12:41 - astropy - WARNING: VerifyWarning: HDU 0:
# WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3). [astropy.io.fits.verify]
# 2026-02-23 15:12:41 - astropy - WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3).
# WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4). [astropy.io.fits.verify]
# 2026-02-23 15:12:41 - astropy - WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4).
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# 2026-02-23 15:12:41 - astropy - WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
# 15:12:42 custom_sunpy_file_handler: Preprocessed input saved
# LVL_0_directory: test_folder\SOLERwave_2011-09-06T22_15_50-AIA_211AA

# %% [markdown]
# ## Example 2: Use Existing Data
#
# The best way to use SOLERwave with existing data is by generating the default folder structure. For this 3 parameters have to be changed:
# - The path where the folder structure shall be created
# - The start time given by the first image in the sequence in format 'JJJJ-MM-DDThh:mm:ss'
# - The instrument_wavelength string: (e.g. SDO_AIA211AA, Kanzelhoehe_H_alpha, GONG_H_alpha_CerroTololo,SECHII_195AA)

# %%
import os
from SOLERwaves_custom_file_handler import create_preprocessed_input,create_folder_structure

path_LVL_0 = create_folder_structure('test_folder', '2023-09-21T12:40:04', instrument_wavelength = 'AIA_211AA', tool_name='SOLERwave')
print(path_LVL_0)
# Out:
# 15:13:49 custom_sunpy_file_handler: folder successfully created
# test_folder\SOLERwave_2023-09-21T12_40_04-SDO_AIA211AA

# %% [markdown]
# After the creation of the folder structure the Data has to be stored in the Input_Fits folder.
#
# To create preprocessed fits files, the create_preprocessed_input needs to be called. It requires a few additional input:
# - The path_LVL_0 which was printed as a result of the create_folder_structure function
# - path_LVL_1_0 which is generated in the cell already, no change needed there
# - The base and end image. It is created in this cell as the first and last file in the input folder when they were sorted $^1$
# - binning: default 1
# - min_exposure_time: is only useful for AIA data, default 1 second, !! Change to None otherwise!!
# - Instrument name: only needed in case of Kanzelhoehe Data, then 'ha2'
#
#
# Note: $^1$ The create_preprocessed_inputs again sorts all files in Input_fits and uses all files between where the name matches base_image_name and end_image_name for the preprocessing

# %%
path_LVL_0 = 'test_folder/SOLERwave_2023-09-21T12_40_04-SDO_AIA211AA'#test_folder/SOLERwave_2011-09-06T22_15_50-AIA_211AA'

path_LVL_1_0 = os.path.join(path_LVL_0, 'Input_Fits')

base_image_name = sorted(os.listdir(path_LVL_1_0))[0]
end_image_name = sorted(os.listdir(path_LVL_1_0))[-1]

create_preprocessed_input(path_LVL_0, path_LVL_1_0, base_image_name, end_image_name, binning=2,min_exposure_time=1.5, Instrument_Name='aia')

print('LVL_0_directory: ' + path_LVL_0)
# Out:
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# 2026-02-23 15:21:32 - astropy - WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU.
# 15:21:32 custom_sunpy_file_handler: binning active 2x2 pixel
# 15:21:32 custom_sunpy_file_handler: process image: 1 of 2
# WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data. [sunpy.map.mapbase]
# 2026-02-23 15:21:32 - sunpy - WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data.
# 2026-02-23 15:21:32 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# 2026-02-23 15:22:05 - astropy - WARNING: VerifyWarning: Verification reported errors:
# WARNING: VerifyWarning: HDU 0: [astropy.io.fits.verify]
# 2026-02-23 15:22:05 - astropy - WARNING: VerifyWarning: HDU 0:
# WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3). [astropy.io.fits.verify]
# 2026-02-23 15:22:05 - astropy - WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3).
# WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4). [astropy.io.fits.verify]
# 2026-02-23 15:22:05 - astropy - WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4).
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# 2026-02-23 15:22:05 - astropy - WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
# 15:22:06 custom_sunpy_file_handler: process image: 2 of 2
# WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data. [sunpy.map.mapbase]
# 2026-02-23 15:22:08 - sunpy - WARNING: SunpyUserWarning: Using propagate_with_solar_surface and SphericalScreen together result in loss of off-disk data.
# 2026-02-23 15:22:08 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# 2026-02-23 15:22:47 - astropy - WARNING: VerifyWarning: Verification reported errors:
# WARNING: VerifyWarning: HDU 0: [astropy.io.fits.verify]
# 2026-02-23 15:22:47 - astropy - WARNING: VerifyWarning: HDU 0:
# WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3). [astropy.io.fits.verify]
# 2026-02-23 15:22:47 - astropy - WARNING: VerifyWarning:     'NAXIS1' card at the wrong place (card 29).  Fixed by moving it to the right place (card 3).
# WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4). [astropy.io.fits.verify]
# 2026-02-23 15:22:47 - astropy - WARNING: VerifyWarning:     'NAXIS2' card at the wrong place (card 30).  Fixed by moving it to the right place (card 4).
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# 2026-02-23 15:22:47 - astropy - WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
# 15:22:47 custom_sunpy_file_handler: Preprocessed input saved
# LVL_0_directory: test_folder/SOLERwave_2023-09-21T12_40_04-SDO_AIA211AA
