# %%
try:
    import sunpy
except ImportError:
    # %pip install "sunpy[all]"==7.1.2

try:
    import numpy
except ImportError:
    # %pip install numpy==2.4.4
    
try:
    import astropy
except ImportError:
    # %pip install astropy==7.2.0
    
try:
    import numba
except ImportError:
    # %pip install numba==0.65.1
    
try:
    import moviepy
except ImportError:
    # %pip install moviepy==2.2.1
# Out:
# ...
#   Obtaining dependency information for sunpy[all]==7.1.2 from https://files.pythonhosted.org/packages/a8/02/9419a986031673f41694975342b7285f676d0adba3460d0f0db7133f771d/sunpy-7.1.2-cp312-abi3-win_amd64.whl.metadata
#   Using cached sunpy-7.1.2-cp312-abi3-win_amd64.whl.metadata (12 kB)
# ...
#   Obtaining dependency information for astropy>=6.1.0 from https://files.pythonhosted.org/packages/ec/bc/f4378f586dd63902c37d16f68f35f7d555b3b32e08ac6b1d633eb0a48805/astropy-7.2.0-cp311-abi3-win_amd64.whl.metadata
#   Using cached astropy-7.2.0-cp311-abi3-win_amd64.whl.metadata (11 kB)
# ...
#   Obtaining dependency information for fsspec>=2023.6.0 from https://files.pythonhosted.org/packages/d5/0c/043d5e551459da400957a1395e0febbf771446ff34291afcbe3d8be2a279/fsspec-2026.4.0-py3-none-any.whl.metadata
#   Using cached fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# ...
